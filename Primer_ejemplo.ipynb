# %% [markdown]
# <a href="https://colab.research.google.com/github/vhvaldiviesor/Programacion-para-analitica-descriptiva-y-predictiva/blob/main/Primer_ejemplo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejemplo de conexion de google drive a google colab**

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
print ('prueba de guardado en git hub')
# Out:
# prueba de guardado en git hub
